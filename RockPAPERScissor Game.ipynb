# %%
pip install sketchpy
# Out:
# Collecting sketchpy
#   Downloading sketchpy-0.1.0-py3-none-any.whl (61 kB)
# Requirement already satisfied: opencv-python in c:\users\lenovo\anaconda3\lib\site-packages (from sketchpy) (4.7.0.68)
# Collecting turtle==0.0.1
#   Downloading turtle-0.0.1.tar.gz (10 kB)
# Collecting svgpathtools
#   Downloading svgpathtools-1.5.1-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: Pillow in c:\users\lenovo\anaconda3\lib\site-packages (from sketchpy) (9.0.1)
# Requirement already satisfied: wheel in c:\users\lenovo\anaconda3\lib\site-packages (from sketchpy) (0.37.1)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from sketchpy) (4.64.0)
# Collecting svg.path
#   Downloading svg.path-6.2-py2.py3-none-any.whl (40 kB)
# Requirement already satisfied: PyYAML>=3.08 in c:\users\lenovo\anaconda3\lib\site-packages (from turtle==0.0.1->sketchpy) (6.0)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\lenovo\anaconda3\lib\site-packages (from opencv-python->sketchpy) (1.21.5)
# Collecting svgwrite
#   Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from svgpathtools->sketchpy) (1.7.3)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm->sketchpy) (0.4.4)
# Building wheels for collected packages: turtle
#   Building wheel for turtle (setup.py): started
#   Building wheel for turtle (setup.py): finished with status 'done'
#   Created wheel for turtle: filename=turtle-0.0.1-py3-none-any.whl size=22201 sha256=178b4fb3793ea9d53a799096178ac1ebed819508d03e8e408e4420093ca2eb50
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\1a\8b\a8\3def5d06272e9213d7691d137f65864acf0b855c476890874e
# Successfully built turtle
# Installing collected packages: svgwrite, turtle, svgpathtools, svg.path, sketchpy
# Successfully installed sketchpy-0.1.0 svg.path-6.2 svgpathtools-1.5.1 svgwrite-1.4.3 turtle-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from  tkinter import *
from random import randint
from PIL import Image,ImageTk
from sketchpy import library as li

root=Tk()
root.title("ROCK")
root.configure(bg="purple")

rockimag=ImageTk.PhotoImage(Image.open(r"C:\Users\Lenovo\Downloads\rock.webp"))
paperimag=ImageTk.PhotoImage(Image.open(r"C:\Users\Lenovo\Downloads\paper.webp"))
scissorsimag=ImageTk.PhotoImage(Image.open(r"C:\Users\Lenovo\Downloads\scissors.webp"))

rock2=ImageTk.PhotoImage(Image.open(r"C:\Users\Lenovo\Downloads\rock.webp"))
paper2=ImageTk.PhotoImage(Image.open(r"C:\Users\Lenovo\Downloads\paper.webp"))
scissors2=ImageTk.PhotoImage(Image.open(r"C:\Users\Lenovo\Downloads\scissors.webp"))

userlabel=Label(root,image=scissorsimag,bg="violet")
comlabel=Label(root,image=rock2,bg="violet")
comlabel.grid(row=1,column=0)
userlabel.grid(row=1,column=4)

playersco=Label(root,text=0,font=100,bg="purple",fg="white")
comsco=Label(root,text=0,font=100,bg="purple",fg="white")
comsco.grid(row=1,column=1)
playersco.grid(row=1,column=3)

user_indicators=Label(root,font=62,text="USER",bg="purple",fg="white").grid(row=0,column=3)
comp_indicators=Label(root,font=62,text="COMPUTER",bg="purple",fg="white").grid(row=0,column=1)

msg=Label(root,font=30,bg="purple",fg="white")
msg.grid(row=8,column=2,)

def updatemsg(x):
    msg['text'] = x

def scoreuupdate():
    score = int(playersco['text'])
    score += 1
    playersco['text'] = str(score)

def scorecupdate():
    score = int(comsco['text'])
    score += 1
    comsco["text"] = str(score)

def winner(player,computer):
    if player == computer:
        updatemsg("!!!---TIE---!!!")
    elif player == "rock":
        if computer == "paper":
            updatemsg("WINNER COMPUTER")
            scorecupdate()
        else:
            updatemsg("WINNER USER")
            scoreuupdate()
    elif player == "paper":
        if computer == "scissor":
            updatemsg("WINNER COMPUTER")
            scorecupdate()
        else:
            updatemsg("WINNER USER")
            scoreuupdate()
    elif player == "scissor":
        if computer == "rock":
            updatemsg("WINNER COMPUTER")
            scorecupdate()
        else:
            updatemsg("WINNER USER")
            scoreuupdate()

comchoice=["rock","paper","scissor",]

def choice(x):

    comChoice=comchoice[randint(0,2)]
    if comChoice == "rock":
        comlabel.configure(image=rockimag)
    elif comChoice == "paper":
        comlabel.configure(image=paperimag)
    else:
        comlabel.configure(image=scissorsimag)

    if x == "rock":
        userlabel.configure(image=rockimag)
    elif x == "paper":
        userlabel.configure(image=paperimag)
    else:
        userlabel.configure(image=scissorsimag)


    winner(x,comChoice)

rock=Button(root,width=20,height=2,text="ROCK",bg="RED",fg="white",command=lambda:choice("rock")).grid(row=2,column=1)
paper=Button(root,width=20,height=2,text="PAPER",bg="GREEN",fg="white",command=lambda:choice("paper")).grid(row=2,column=2)
scissor=Button(root,width=20,height=2,text="SCISSOR",bg="Orange",fg="white",command=lambda:choice("scissor")).grid(row=2,column=3)

root.mainloop()
